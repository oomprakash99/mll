# %%
print("dfasdfafds")
# Out:
# dfasdfafds

# %%
import numpy as np
m = np.array([[1, 2],[2, 3]])
print("Printing the Original square array:\n",m)
w, v = np.linalg.eig(m)
print("Printing the Eigen values of the given square array:\n",w)
print("Printing Right eigenvectors of the given square array:\n",v)
# Out:
# Printing the Original square array:
#  [[1 2]
#  [2 3]]
# Printing the Eigen values of the given square array:
#  [-0.23606798  4.23606798]
# Printing Right eigenvectors of the given square array:
#  [[-0.85065081 -0.52573111]
#  [ 0.52573111 -0.85065081]]

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
print(gfg)
w = gfg.transpose()
print(w)
# Out:
# [[ 4  1  9]
#  [12  3  1]
#  [ 4  5  6]]
# [[ 4 12  4]
#  [ 1  3  5]
#  [ 9  1  6]]

# %%
x = np.array([[0, 3, 4], [1, 2, 4], [3, 4, 5]])
print("Shape of array:\n", np.shape(x))
print("Covariance matrix of x:\n", np.cov(x))
# Out:
# Shape of array:
#  (3, 3)
# Covariance matrix of x:
#  [[4.33333333 2.83333333 2.        ]
#  [2.83333333 2.33333333 1.5       ]
#  [2.         1.5        1.        ]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 2.71739889  1.62816413  3.97482651]
#  [ 4.09993631 -1.62665868 -0.28428408]]

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 0, 1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
         np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
n, p = 10, 0.5 # number of trials and probability of success
s = np.random.binomial(n, p, 1000)

count, bins, ignored = plt.hist(s, 30, density=True)
plt.show()

# %%
lam = 3
size = 1000

poisson_array = np.random.poisson(lam, size)

plt.hist(poisson_array, bins=range(11))
plt.show()

# %%
scale = 2
size = 1000

exponential_array = np.random.exponential(scale, size)

plt.hist(exponential_array, bins=range(11))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

sample_size = [1,10,100,1000]
for i in sample_size:
  uniform_array = np.random.uniform(0, 1, (1000, i))
  sample_means = np.mean(uniform_array, axis=1)
  plt.hist(sample_means, bins=30)
  plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

# number of sample
num = [1, 10, 50, 100]
# list of sample means
means = []

# Generating 1, 10, 30, 100 random numbers from -40 to 40
# taking their mean and appending it to list means.
for j in num:
	# Generating seed so that we can get same result
	# every time the loop is run...
	numpy.random.seed(1)
	x = [numpy.mean(
		numpy.random.randint(
			-40, 40, j)) for _i in range(1000)]
	means.append(x)
k = 0

# plotting all the means in one figure
fig, ax = plt.subplots(2, 2, figsize =(8, 8))
for i in range(0, 2):
	for j in range(0, 2):
		# Histogram for each x stored in means
		ax[i, j].hist(means[k], 10, density = True)
		ax[i, j].set_title(label = num[k])
		k = k + 1
plt.show()
